# %% [markdown]
# ## Assignment 02 - Logistic Regression Classifier using PyTorch on CIFAR-10 Dataset
#
# #### Submitted By:
# 1. Dhruvan Ganesh
# 2. Sheikh Mastura Farzana

# %% [markdown]
# ### Imports

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from sklearn import preprocessing
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms, datasets

# %% [markdown]
# ### Environment Information

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
data_dir = "~/.datasets"
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

print("Device:", device)
print("Data Dir:", data_dir)
print("Set Random Seed :", seed)
# Out:
# Device: cuda:0
# Data Dir: ~/.datasets
# Set Random Seed : 42

# %%
## Plotting Utils


def plotLine(arr: [], title=""):
    plt.plot(np.squeeze([range(1, len(arr) + 1)]), np.squeeze(arr))
    plt.title(title)
    plt.show()


def plotLines(arr: [], arr2: [], title="", labels=[]):
    plt.plot(np.squeeze([range(1, len(arr) + 1)]), np.squeeze(arr), label=labels[0])
    plt.plot(np.squeeze([range(1, len(arr2) + 1)]), np.squeeze(arr2), label=labels[1])
    plt.title(title)
    plt.legend()
    plt.show()


def plotNumpyArray(ndarray, title="", xlabel=""):
    df = pd.DataFrame(
        ndarray, columns=[f"Param {i}" for i in range(1, ndarray.shape[1] + 1)]
    )
    df.plot.line()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.show()

# %% [markdown]
# ### Class to load CIFAR10

# %%
class CIFAR10Data:
    def __init__(self):
        transform = transforms.Compose(
            [
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ]
        )

        self.trainset = datasets.CIFAR10(
            root=data_dir, train=True, download=True, transform=transform
        )
        self.testset = datasets.CIFAR10(
            root=data_dir, train=False, download=True, transform=transform
        )

        self.classes = (
            "plane",
            "car",
            "bird",
            "cat",
            "deer",
            "dog",
            "frog",
            "horse",
            "ship",
            "truck",
        )

    def get_cifar10_data(self):
        return self.trainset, self.testset, self.classes

    def get_cifar10_batch_loaders(self, batch_size=64):

        train_dataloader = DataLoader(
            self.trainset,
            shuffle=True,
            batch_size=batch_size,
            drop_last=True,
            num_workers=4,
        )
        test_dataloader = DataLoader(
            self.testset,
            shuffle=False,
            batch_size=batch_size,
            drop_last=True,
            num_workers=4,
        )

        return train_dataloader, test_dataloader

# %% [markdown]
# ### Model Trainer Class

# %%
class Trainer(object):
    """
    The Trainer class,
    which makes use of Torch's Module, Loss, Optimizer implementations
    """

    def __init__(
        self,
        model: nn.Module,
        loss: nn.modules.loss._Loss,
        optimizer: torch.optim.Optimizer,
    ):
        self._model = model
        self._loss = loss
        self._optimizer = optimizer

    def __str__(self):
        return f"""Trainer:\nArch:\n{self._model}\nLoss: {self._loss}"""

    def predict_classes(self, dataloader, retLabels=False):
        predY: [int] = []
        actualY: [int] = []
        for X, Y in dataloader:
            X, Y = X.to(device), Y
            X = X.reshape(dataloader.batch_size, -1).to(device)
            class_probabilities = self._model(X)
            class_predictions = torch.argmax(class_probabilities, dim=1)
            predY.extend(class_predictions.tolist())
            actualY.extend(Y.tolist())
        if retLabels:
            return predY, actualY
        else:
            return predY

    def fit(
        self,
        train_dataloader: torch.utils.data.DataLoader,
        test_dataloader: torch.utils.data.DataLoader,
        epochs=100,
        track_metrics=True,
        log=True,
        log_interval=10,
        plot_learning_curve=True,
        plot_gradient_norm=True,
    ):
        train_losses = []
        test_losses = []
        train_accs = []
        test_accs = []
        grad_norms = []

        for epoch in range(1, epochs + 1):
            self._model.train()
            train_loss = 0.0
            train_acc = 0.0
            grad_norm = []
            for batch_id, (X, Y) in enumerate(train_dataloader):
                X, Y = X.to(device), Y.to(device)
                X = X.view(train_dataloader.batch_size, -1).to(device)
                self._optimizer.zero_grad()
                class_probabilities = self._model(X)
                loss = self._loss(class_probabilities, Y)

                if track_metrics:
                    train_loss += loss.item()
                    class_prediction = torch.argmax(class_probabilities, dim=1)
                    train_acc += (class_prediction == Y.data).sum().item()

                loss.backward()

                if plot_gradient_norm:
                    grads = torch.Tensor(
                        [
                            p.grad.data.norm(2).cpu()
                            for p in list(
                                filter(
                                    lambda p: p.grad is not None,
                                    self._model.parameters(),
                                )
                            )
                        ]
                    ).to(device)
                    grad_norm.append(grads)

                self._optimizer.step()

            if track_metrics:
                train_losses.append(train_loss)
                train_acc /= len(train_dataloader.dataset)
                train_accs.append(train_acc)

            test_loss, test_acc = self.validation(test_dataloader)
            test_accs.append(test_acc)
            if log and epoch % log_interval == 0:
                test_losses.append(test_loss)
                print(
                    "Epoch: {}\tTraining Loss: {:.4f}\tTraining Acc: {:.4f}\tTest Acc: {:.4f}\t".format(
                        epoch, train_loss, train_acc, test_acc
                    )
                )

            if plot_gradient_norm:
                grad_norm = torch.stack(grad_norm)
                grad_norm_parameters = torch.sqrt(torch.sum(grad_norm, 0))
                grad_norms.append(grad_norm_parameters)

        if plot_learning_curve:
            plotLine(train_losses, title="Training Loss")
            plotLine(test_losses, title="Test Loss")
            plotLines(train_accs, test_accs, title="Accuracy", labels=["train", "test"])

        if plot_gradient_norm:
            grad_norms = torch.stack(grad_norms).cpu().numpy()
            grad_norms = grad_norms.reshape(epochs, -1)
            plotNumpyArray(
                grad_norms,
                title="Gradient Norms of The Learnable Parameters",
                xlabel="Epochs",
            )

            min_max_scaler = preprocessing.MinMaxScaler()
            grad_norms_scaled = min_max_scaler.fit_transform(grad_norms)
            plotNumpyArray(
                grad_norms_scaled,
                title="Scaled Gradient Norms of The Learnable Parameters",
                xlabel="Epochs",
            )

        return train_accs, test_accs

    def validation(self, testloader):
        test_loss = 0
        accuracy = 0

        for testX, testY in testloader:
            testX, testY = testX.to(device), testY.to(device)
            testX = testX.reshape(testloader.batch_size, -1).to(device)

            predictions = self._model(testX)
            test_loss += self._loss(predictions, testY).item()

            argmax = torch.argmax(predictions, dim=1)
            accuracy += (argmax == testY.data).sum().item()

        return test_loss, accuracy / len(testloader.dataset)

# %% [markdown]
# ### Initialize custom Trainer class with a Model, Loss Function and Optimizer

# %%
cifar10_data = CIFAR10Data()


def run_model_trainer(learning_rate, batch_size, print_trainer_info=False, **kwargs):

    _model = nn.Sequential(
        nn.Linear(1024 * 3, 128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, 10),
        nn.Softmax(-1),
    )

    _trainer = Trainer(
        model=_model.to(device),
        loss=nn.CrossEntropyLoss(),
        optimizer=torch.optim.Adam(_model.parameters(), lr=learning_rate),
    )

    if print_trainer_info:
        print(_trainer)

    _train_dataloader, _test_dataloader = cifar10_data.get_cifar10_batch_loaders(
        batch_size=batch_size
    )

    _train_accs, _test_accs = _trainer.fit(
        _train_dataloader, _test_dataloader, **kwargs
    )

    return _trainer, (_train_dataloader, _test_dataloader), (_train_accs, _test_accs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Train the model on CIFAR10

# %%
trainer, (train_dataloader, test_dataloader), _ = run_model_trainer(
    batch_size=64,
    learning_rate=1e-3,
    print_trainer_info=True,
    epochs=500
)
# Out:
# Trainer:
# Arch:
# Sequential(
#   (0): Linear(in_features=3072, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=10, bias=True)
#   (5): Softmax(dim=-1)
# )
# Loss: CrossEntropyLoss()
# Epoch: 10	Training Loss: 1506.6404	Training Acc: 0.5290	Test Acc: 0.4733
# Epoch: 20	Training Loss: 1475.4697	Training Acc: 0.5696	Test Acc: 0.4881
# Epoch: 30	Training Loss: 1461.9165	Training Acc: 0.5876	Test Acc: 0.5000
# Epoch: 40	Training Loss: 1453.7399	Training Acc: 0.5984	Test Acc: 0.4931
# Epoch: 50	Training Loss: 1449.4509	Training Acc: 0.6040	Test Acc: 0.4999
# Epoch: 60	Training Loss: 1444.0293	Training Acc: 0.6108	Test Acc: 0.5043
# Epoch: 70	Training Loss: 1446.0859	Training Acc: 0.6086	Test Acc: 0.4907
# Epoch: 80	Training Loss: 1443.3549	Training Acc: 0.6121	Test Acc: 0.5066
# Epoch: 90	Training Loss: 1441.6380	Training Acc: 0.6145	Test Acc: 0.5023
# Epoch: 100	Training Loss: 1449.7463	Training Acc: 0.6041	Test Acc: 0.5008
# Epoch: 110	Training Loss: 1446.7728	Training Acc: 0.6080	Test Acc: 0.5021
# Epoch: 120	Training Loss: 1446.9080	Training Acc: 0.6078	Test Acc: 0.4971
# Epoch: 130	Training Loss: 1449.7833	Training Acc: 0.6043	Test Acc: 0.5032
# Epoch: 140	Training Loss: 1451.8867	Training Acc: 0.6017	Test Acc: 0.5009
# Epoch: 150	Training Loss: 1456.5979	Training Acc: 0.5957	Test Acc: 0.4993
# Epoch: 160	Training Loss: 1456.5288	Training Acc: 0.5956	Test Acc: 0.4935
# Epoch: 170	Training Loss: 1462.5923	Training Acc: 0.5878	Test Acc: 0.4844
# Epoch: 180	Training Loss: 1456.2481	Training Acc: 0.5961	Test Acc: 0.4928
# Epoch: 190	Training Loss: 1463.3111	Training Acc: 0.5870	Test Acc: 0.5024
# Epoch: 200	Training Loss: 1469.9333	Training Acc: 0.5787	Test Acc: 0.4895
# Epoch: 210	Training Loss: 1468.1182	Training Acc: 0.5811	Test Acc: 0.4865
# Epoch: 220	Training Loss: 1469.2140	Training Acc: 0.5797	Test Acc: 0.4872
# Epoch: 230	Training Loss: 1466.2360	Training Acc: 0.5836	Test Acc: 0.4924
# Epoch: 240	Training Loss: 1465.3095	Training Acc: 0.5846	Test Acc: 0.4923
# Epoch: 250	Training Loss: 1475.4086	Training Acc: 0.5716	Test Acc: 0.4829
# Epoch: 260	Training Loss: 1460.5550	Training Acc: 0.5908	Test Acc: 0.4922
# Epoch: 270	Training Loss: 1477.3469	Training Acc: 0.5693	Test Acc: 0.4809
# Epoch: 280	Training Loss: 1472.3022	Training Acc: 0.5756	Test Acc: 0.4928
# Epoch: 290	Training Loss: 1472.4974	Training Acc: 0.5754	Test Acc: 0.4888
# Epoch: 300	Training Loss: 1483.2457	Training Acc: 0.5617	Test Acc: 0.4749
# Epoch: 310	Training Loss: 1476.6221	Training Acc: 0.5702	Test Acc: 0.4803
# Epoch: 320	Training Loss: 1485.7769	Training Acc: 0.5585	Test Acc: 0.4739
# Epoch: 330	Training Loss: 1479.6226	Training Acc: 0.5664	Test Acc: 0.4676
# Epoch: 340	Training Loss: 1484.3649	Training Acc: 0.5603	Test Acc: 0.4740
# Epoch: 350	Training Loss: 1489.5396	Training Acc: 0.5537	Test Acc: 0.4755
# Epoch: 360	Training Loss: 1500.8297	Training Acc: 0.5392	Test Acc: 0.4677
# Epoch: 370	Training Loss: 1490.2012	Training Acc: 0.5528	Test Acc: 0.4772
# Epoch: 380	Training Loss: 1490.4328	Training Acc: 0.5526	Test Acc: 0.4785
# Epoch: 390	Training Loss: 1502.0967	Training Acc: 0.5375	Test Acc: 0.4754
# Epoch: 400	Training Loss: 1496.4177	Training Acc: 0.5449	Test Acc: 0.4739
# Epoch: 410	Training Loss: 1490.8036	Training Acc: 0.5520	Test Acc: 0.4816
# Epoch: 420	Training Loss: 1506.8743	Training Acc: 0.5315	Test Acc: 0.4666
# Epoch: 430	Training Loss: 1496.7388	Training Acc: 0.5445	Test Acc: 0.4728
# Epoch: 440	Training Loss: 1496.3991	Training Acc: 0.5449	Test Acc: 0.4632
# Epoch: 450	Training Loss: 1486.4120	Training Acc: 0.5576	Test Acc: 0.4741
# Epoch: 460	Training Loss: 1496.8944	Training Acc: 0.5443	Test Acc: 0.4817
# Epoch: 470	Training Loss: 1500.5232	Training Acc: 0.5397	Test Acc: 0.4773
# Epoch: 480	Training Loss: 1489.0521	Training Acc: 0.5543	Test Acc: 0.4816
# Epoch: 490	Training Loss: 1499.4419	Training Acc: 0.5410	Test Acc: 0.4735
# Epoch: 500	Training Loss: 1494.6547	Training Acc: 0.5471	Test Acc: 0.4699

# %% [markdown]
# ### Plot Confusion Matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(predicted, actual, title=""):
    cf_matrix = confusion_matrix(predicted, actual)
    cf_matrix = cf_matrix.astype("float") / cf_matrix.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10, 10))
    sns.heatmap(cf_matrix, annot=True, cmap="Blues")
    plt.title(title)
    plt.ylabel("Predicted Label")
    plt.xlabel("Actual Label")
    plt.show()

# %%
cfPredictedY, cfActualY = trainer.predict_classes(train_dataloader, True)

plot_confusion_matrix(cfPredictedY, cfActualY, title="Confusion Matrix")

# %% [markdown]
# ### HyperOpt: do random search to select the best parameters

# %%
import hyperopt
from hyperopt import hp, fmin, tpe


def tune_learning_rate(search_space_n_times, max_train_epochs):
    def objective(args):
        print("Evaluating: ", args)

        _, _, (_train_acc, _test_acc) = run_model_trainer(
            **args,
            epochs=max_train_epochs,
            track_metrics=False,
            log=False,
            plot_learning_curve=False,
            plot_gradient_norm=False,
        )

        final_accuracy = _test_acc[-1]
        print(f"Validation Accuracy: {final_accuracy}")

        # maximize test accuracy
        return -final_accuracy

    space = {
        "batch_size": hp.choice("batch_size", [32, 64, 128, 256]),
        "learning_rate": hp.loguniform("learning_rate", np.log(1e-4), np.log(0.01)),
    }

    best = fmin(objective, space, algo=tpe.suggest, max_evals=search_space_n_times)

    return hyperopt.space_eval(space, best)


best_params = tune_learning_rate(search_space_n_times=20, max_train_epochs=100)
print("Best Parameters: ", best_params)
# Out:
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.004381719028810083}
# Validation Accuracy: 0.1
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.0001844530924074938}
# Validation Accuracy: 0.511
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.00027406372906480853}
# Validation Accuracy: 0.5151
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.001775012218239829}
# Validation Accuracy: 0.5105
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.0006844721833575595}
# Validation Accuracy: 0.5162
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.0006877968086690827}
# Validation Accuracy: 0.5192
# Evaluating:
# {'batch_size': 128, 'learning_rate': 0.0010682134108252364}
# Validation Accuracy: 0.51
# Evaluating:
# {'batch_size': 64, 'learning_rate': 0.0009972343466658614}
# Validation Accuracy: 0.4912
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.004811937573033714}
# Validation Accuracy: 0.2094
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.0036067273946494226}
# Validation Accuracy: 0.3605
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.001002877123251938}
# Validation Accuracy: 0.4438
# Evaluating:
# {'batch_size': 256, 'learning_rate': 0.001318782857465809}
# Validation Accuracy: 0.5095
# Evaluating:
# {'batch_size': 128, 'learning_rate': 0.00274844659330941}
# Validation Accuracy: 0.3358
# Evaluating:
# {'batch_size': 128, 'learning_rate': 0.004500770074302997}
# Validation Accuracy: 0.1671
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.004552370896679534}
# Validation Accuracy: 0.1
# Evaluating:
# {'batch_size': 64, 'learning_rate': 0.004995248623450018}
# Validation Accuracy: 0.0998
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.00021038882122002793}
# Validation Accuracy: 0.5159
# Evaluating:
# {'batch_size': 64, 'learning_rate': 0.0016856816765868008}
# Validation Accuracy: 0.3404
# Evaluating:
# {'batch_size': 32, 'learning_rate': 0.003652503147292769}
# Validation Accuracy: 0.1863
# Evaluating:
# {'batch_size': 128, 'learning_rate': 0.009826000547139021}
# Validation Accuracy: 0.0998
# 100%|██████████| 20/20 [2:17:48<00:00, 413.40s/trial, best loss: -0.5192]
# Best Parameters:  {'batch_size': 256, 'learning_rate': 0.0006877968086690827}

# %% [markdown]
# ### HyperOpt: Train with the Best Parameters

# %%
trainer, (train_dataloader, _), _ = run_model_trainer(
    **best_params,
    epochs=500
)
# Out:
# Epoch: 10	Training Loss: 371.1479	Training Acc: 0.5602	Test Acc: 0.4928
# Epoch: 20	Training Loss: 357.6612	Training Acc: 0.6306	Test Acc: 0.5083
# Epoch: 30	Training Loss: 349.9240	Training Acc: 0.6696	Test Acc: 0.5119
# Epoch: 40	Training Loss: 345.6800	Training Acc: 0.6903	Test Acc: 0.5153
# Epoch: 50	Training Loss: 342.8340	Training Acc: 0.7042	Test Acc: 0.5140
# Epoch: 60	Training Loss: 339.8327	Training Acc: 0.7192	Test Acc: 0.5138
# Epoch: 70	Training Loss: 337.7649	Training Acc: 0.7291	Test Acc: 0.5145
# Epoch: 80	Training Loss: 337.1635	Training Acc: 0.7321	Test Acc: 0.5175
# Epoch: 90	Training Loss: 335.6562	Training Acc: 0.7395	Test Acc: 0.5109
# Epoch: 100	Training Loss: 335.5991	Training Acc: 0.7397	Test Acc: 0.5131
# Epoch: 110	Training Loss: 334.8021	Training Acc: 0.7435	Test Acc: 0.5160
# Epoch: 120	Training Loss: 333.9268	Training Acc: 0.7478	Test Acc: 0.5164
# Epoch: 130	Training Loss: 332.8614	Training Acc: 0.7536	Test Acc: 0.5142
# Epoch: 140	Training Loss: 332.7589	Training Acc: 0.7534	Test Acc: 0.5214
# Epoch: 150	Training Loss: 332.1270	Training Acc: 0.7568	Test Acc: 0.5202
# Epoch: 160	Training Loss: 331.4600	Training Acc: 0.7599	Test Acc: 0.5149
# Epoch: 170	Training Loss: 331.2676	Training Acc: 0.7611	Test Acc: 0.5173
# Epoch: 180	Training Loss: 330.8178	Training Acc: 0.7635	Test Acc: 0.5138
# Epoch: 190	Training Loss: 330.6673	Training Acc: 0.7640	Test Acc: 0.5188
# Epoch: 200	Training Loss: 330.6204	Training Acc: 0.7642	Test Acc: 0.5133
# Epoch: 210	Training Loss: 330.0845	Training Acc: 0.7672	Test Acc: 0.5132
# Epoch: 220	Training Loss: 330.0009	Training Acc: 0.7675	Test Acc: 0.5185
# Epoch: 230	Training Loss: 329.2204	Training Acc: 0.7716	Test Acc: 0.5268
# Epoch: 240	Training Loss: 329.2489	Training Acc: 0.7713	Test Acc: 0.5148
# Epoch: 250	Training Loss: 329.7461	Training Acc: 0.7686	Test Acc: 0.5145
# Epoch: 260	Training Loss: 328.7508	Training Acc: 0.7740	Test Acc: 0.5157
# Epoch: 270	Training Loss: 328.4078	Training Acc: 0.7755	Test Acc: 0.5211
# Epoch: 280	Training Loss: 328.7410	Training Acc: 0.7739	Test Acc: 0.5176
# Epoch: 290	Training Loss: 328.3040	Training Acc: 0.7759	Test Acc: 0.5205
# Epoch: 300	Training Loss: 328.3276	Training Acc: 0.7761	Test Acc: 0.5201
# Epoch: 310	Training Loss: 328.1231	Training Acc: 0.7771	Test Acc: 0.5224
# Epoch: 320	Training Loss: 327.9733	Training Acc: 0.7777	Test Acc: 0.5211
# Epoch: 330	Training Loss: 327.8514	Training Acc: 0.7784	Test Acc: 0.5179
# Epoch: 340	Training Loss: 328.0462	Training Acc: 0.7774	Test Acc: 0.5228
# Epoch: 350	Training Loss: 327.1033	Training Acc: 0.7820	Test Acc: 0.5204
# Epoch: 360	Training Loss: 327.4556	Training Acc: 0.7804	Test Acc: 0.5151
# Epoch: 370	Training Loss: 327.4946	Training Acc: 0.7802	Test Acc: 0.5182
# Epoch: 380	Training Loss: 326.4467	Training Acc: 0.7857	Test Acc: 0.5224
# Epoch: 390	Training Loss: 326.6432	Training Acc: 0.7845	Test Acc: 0.5162
# Epoch: 400	Training Loss: 326.4684	Training Acc: 0.7856	Test Acc: 0.5200
# Epoch: 410	Training Loss: 326.5621	Training Acc: 0.7850	Test Acc: 0.5157
# Epoch: 420	Training Loss: 326.1255	Training Acc: 0.7871	Test Acc: 0.5209
# Epoch: 430	Training Loss: 326.5359	Training Acc: 0.7851	Test Acc: 0.5171
# Epoch: 440	Training Loss: 326.9292	Training Acc: 0.7830	Test Acc: 0.5242
# Epoch: 450	Training Loss: 326.1383	Training Acc: 0.7872	Test Acc: 0.5216
# Epoch: 460	Training Loss: 326.7660	Training Acc: 0.7841	Test Acc: 0.5225
# Epoch: 470	Training Loss: 325.8364	Training Acc: 0.7887	Test Acc: 0.5237
# Epoch: 480	Training Loss: 326.0557	Training Acc: 0.7874	Test Acc: 0.5170
# Epoch: 490	Training Loss: 325.7472	Training Acc: 0.7893	Test Acc: 0.5187
# Epoch: 500	Training Loss: 325.6816	Training Acc: 0.7896	Test Acc: 0.5170
